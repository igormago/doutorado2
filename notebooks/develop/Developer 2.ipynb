# %%
#imports 
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import scipy.stats as stats

matplotlib.style.use('ggplot') #style of plots

#to plot in this notebook
# %matplotlib inline

champs = ['Brazil - Série A','Brazil - Série B','Spain - La Liga 1',
          'Germany - Bundesliga','Italy - Serie A', 'England - Premier League',
          'France - Ligue 1', 'Portugal - Primeira Liga', 'Netherlands - Eredivise']

# %%
df =  pd.read_csv("../data/resumeMatchesByYear_avg.csv") 

df.index = pd.to_datetime(df.YR,format='%Y')

fig, (ax1) = plt.subplots(1,1)
fig.set_figwidth(16)
fig.set_figheight(10)


yticks= np.arange(0.38,0.62,0.02)
xticks = pd.to_datetime(np.arange(2006,2016,1),format='%Y')

def plotAx(df, ax):
    ax.plot(df, marker='.')
    ax.set_yticks(yticks)
    ax.set_xticks(xticks)
    ax.set_xlabel("Years")
    ax.set_ylabel("Prob. (%)")
    ax.legend(champs)
    
ax1.legend(champs,loc='best')
ax1.set_title('Home Factor')

for c in champs:
    plotAx(df[df.CHAMP == c]['PCT_H'],ax1)

plt.show()

# %%
df =  pd.read_csv("../data/resumeMatchesByYear_avg.csv") 

fig, (ax1) = plt.subplots(1,1)
fig.set_figwidth(16)
fig.set_figheight(10)

yticks= np.arange(0.35,0.64,0.05)

def plotAx(df, ax):
    ax.boxplot(df, showmeans=True)
    ax.set_xticklabels(champs, rotation=45)
    ax.set_ylabel("Prob. Home Winner")
    ax.set_yticks(yticks)
    
ax1.set_title('Home Factor')
listChamps = []
for c in champs:
    listChamps.append(df[df.CHAMP == c]['PCT_H'])
    
plotAx(listChamps,ax1)

fig.suptitle("Probabilty Results")
    
plt.show()

# %%
df =  pd.read_csv("../data/resumeMatchesByYear_avg.csv") 

df.index = pd.to_datetime(df.YR,format='%Y')

fig, (ax1) = plt.subplots(1,1)
fig.set_figwidth(16)
fig.set_figheight(10)

yticks= np.arange(0.40,0.69,0.02)
xticks = pd.to_datetime(np.arange(2006,2016,1),format='%Y')

champs = ['Brazil - Série A','Spain - La Liga 1',
          'Germany - Bundesliga','Italy - Serie A', 'England - Premier League',
          'France - Ligue 1', 'Portugal - Primeira Liga', 'Netherlands - Eredivise']

def plotAx(df, ax):
    ax.plot(df, marker='.')
    ax.set_yticks(yticks)
    ax.set_xticks(xticks)
    ax.set_xlabel("Years")
    ax.set_ylabel("Prob. (%)")
    ax.legend(champs)
    
ax1.legend(champs,loc='best')
ax1.set_title('Home Factor')

for c in champs:
    plotAx(df[df.CHAMP == c]['PCT_F'],ax1)

plt.show()

# %%
df =  pd.read_csv("../data/resumeMatchesByYear_avg.csv") 

fig, (ax1) = plt.subplots(1,1)
fig.set_figwidth(16)
fig.set_figheight(10)

yticks= np.arange(0.40,0.69,0.02)

def plotAx(df, ax):
    ax.boxplot(df, showmeans=True)
    ax.set_xticklabels(champs, rotation=45)
    ax.set_ylabel("Prob. Favorite Winner")
    ax.set_yticks(yticks)
    
ax1.set_title('Favorite Factor')
listChamps = []
for c in champs:
    listChamps.append(df[df.CHAMP == c]['PCT_F'])
    
plotAx(listChamps,ax1)

fig.suptitle("Probabilty Results")
    
plt.show()

# %%
df =  pd.read_csv("../data/resumeMatchesByYear_avg.csv") 

fig, (ax1,ax2) = plt.subplots(1,2)
fig.set_figwidth(16)
fig.set_figheight(10)

yticks= np.arange(-150,101,25)

def plotAx(df, ax):
    ax.boxplot(df, showmeans=True)
    ax.set_xticklabels(champs, rotation=80)
    ax.set_ylabel("Profit/Loss")
    ax.set_yticks(yticks)
    
ax1.set_title('Profit/Loss Home')
ax2.set_title('Profit/Loss Away')
listChamps = []
for c in champs:
    listChamps.append(df[df.CHAMP == c]['PLH'])
    
plotAx(listChamps,ax1)

listChamps = []
for c in champs:
    listChamps.append(df[df.CHAMP == c]['PLA'])
        
plotAx(listChamps,ax2)   
plt.show()

# %%
df =  pd.read_csv("../data/resumeMatchesByYear_avg.csv") 

fig, (ax1,ax2) = plt.subplots(1,2)
fig.set_figwidth(16)
fig.set_figheight(10)

yticks= np.arange(-150,101,25)

def plotAx(df, ax):
    ax.boxplot(df, showmeans=True)
    ax.set_xticklabels(champs, rotation=80)
    ax.set_ylabel("Profit/Loss")
    ax.set_yticks(yticks)
    
ax1.set_title('Profit/Loss Favorite')
ax2.set_title('Profit/Loss Underdog')
listChamps = []
for c in champs:
    listChamps.append(df[df.CHAMP == c]['PLF'])
    
plotAx(listChamps,ax1)

listChamps = []
for c in champs:
    listChamps.append(df[df.CHAMP == c]['PLU'])
        
plotAx(listChamps,ax2)   
plt.show()

# %%
df =  pd.read_csv("../data/resumeMatchesByYear_avg.csv") 

fig, (ax1,ax2) = plt.subplots(1,2)
fig.set_figwidth(16)
fig.set_figheight(10)

yticks= np.arange(-150,101,50)

def plotAx(df, ax):
    ax.boxplot(df, showmeans=True)
    ax.set_xticklabels(champs, rotation=80)
    ax.set_ylabel("Profit/Loss")
    ax.set_yticks(yticks)
    
ax1.set_title('Profit/Loss Favorite')
ax2.set_title('Profit/Loss Underdog')
listChamps = []
for c in champs:
    listChamps.append(df[df.CHAMP == c]['PLF'])
    
plotAx(listChamps,ax1)

listChamps = []
for c in champs:
    listChamps.append(df[df.CHAMP == c]['PLU'])
        
plotAx(listChamps,ax2)   
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import cross_validation

df =  pd.read_csv("../data/matches-tables.csv") 
df = df[df.championship_id < 90]
champs_cv = []

for i in range(21,31):
    df = df[df.championship_id == i]
    df = df[df.odd_home.notnull()]
    df = df[df.odd_draw.notnull()]
    df = df[df.odd_away.notnull()]

    features = list(df.columns)
    features.remove('match_id')
    features.remove('column_result')
    features.remove('match_date')
    features.remove('goals_home')
    features.remove('goals_away')

    target = 'column_result'

    X = df[features]
    y = df[target]
    
    clf = RandomForestClassifier(n_estimators=1000)
    clf.fit(X, y)
    scores = cross_validation.cross_val_score(clf, X, y, cv=10)
    champs_cv.append(scores.mean())
    print("%0.2f" % (scores.mean()))
    

print(champs_cv)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-805c57c3afbe> in <module>()
#      25
#      26     clf = RandomForestClassifier(n_estimators=1000)
# ---> 27     clf.fit(X, y)
#      28     scores = cross_validation.cross_val_score(clf, X, y, cv=10)
#      29     champs_cv.append(scores.mean())
#
# /home/igormago/anaconda3/lib/python3.5/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     210         """
#     211         # Validate or convert input data
# --> 212         X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     213         if issparse(X):
#     214             # Pre-sort indices to avoid that each individual tree of the
#
# ...

# %%
x = [0.48868342026236766, 0.48278161620266885, 0.48154308154308156, 0.48981684113263058, 0.4774066576698156, 
     0.43005554426607057, 0.4389521100047416, 0.49032547585179176, 0.4839568515884306, 0.45279392174129018, 
     0.44761712840660206, 0.43161778319673055, 0.56097281492018325, 0.51209498972656864, 0.57609846688794053, 
     0.52419575445891231, 0.48376068376068371, 0.52306719675140734, 0.5361085145295672, 0.497380275011854,
     0.4609372530425162, 0.54880670143828048, 0.54787385129490396, 0.53108029081713293, 0.42487141276614959, 
     0.51135823793718527, 0.47866287339971547, 0.54463286594865545, 0.48143274853801171, 0.42710149420675736, 
     0.48844351870667663, 0.46046535257061577, 0.51755966492808603, 0.52426110320847163, 0.44189766689766685, 
     0.47799510036352144, 0.5647378147378147, 0.50014800514800517, 0.42378028404344192, 0.48624263361105469, 
     0.42757027704396122, 0.39935897435897438, 0.4215979137031769, 0.4821303258145363, 0.39211590132642765, 
     0.41607227528280166, 0.43846858136331823, 0.45803242513768827, 0.50604788999525829, 0.41762040235724446, 
     0.44702261772339635, 0.46425287356321843, 0.49353355580274388, 0.44310344827586212, 0.44618067694263469,
     0.45224455744477998, 0.46835505058530646, 0.52474972191323688, 0.47529185867895551, 0.46446421950315164, 
     0.49912714097496708, 0.44973649538866922, 0.54301712779973654, 0.48952898550724644, 0.43858695652173907, 
     0.5521480331262939, 0.54666666666666663, 0.47807971014492756, 0.50387931034482758, 0.53024392181789293, 
     0.54688013136288993, 0.47424837120610197, 0.48943243815880078, 0.5679638752052546, 0.49143492769744163, 
     0.56684119921606024, 0.49183537263626248, 0.45794957360029664, 0.48261772339636633, 0.51896922506488696]

# %%
championships = ['Brazil - Série A','Spain - La Liga 1',
          'Germany - Bundesliga','Italy - Serie A', 'England - Premier League',
          'France - Ligue 1', 'Portugal - Primeira Liga', 'Netherlands - Eredivise']

list_champs_cv = []

for c in champs:
    for i in range(1,11):
        list_champs_cv.append(c)
    

df2 = pd.DataFrame()
df2['champ'] = list_champs_cv
df2['cv_score'] = x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-662cc9ddef92> in <module>()
#      12 df2 = pd.DataFrame()
#      13 df2['champ'] = list_champs_cv
# ---> 14 df2['cv_score'] = x
#
# NameError: name 'x' is not defined

# %%
df =  pd.read_csv("../data/resumeMatchesByYear_avg.csv") 

fig, ((ax1,ax2),(ax3,ax4),(ax5,ax6),(ax7,ax8)) = plt.subplots(4,2)
fig.set_figwidth(16)
fig.set_figheight(10)
fig.tight_layout()

yticks= np.arange(0.30,0.69,0.05)
xticks = ('Home','Favorite','Random Forest')

def plotAx(df, ax):
    ax.boxplot(df, showmeans=True)
    ax.set_ylabel("Prob. Winner")
    ax.set_yticks(yticks)
    ax.set_xticklabels(xticks)

axis = [ax1,ax2,ax3,ax4,ax5,ax6,ax7,ax8]
for c, ax in zip(champs, axis):
    df3 = df2[df2.champ == c]
    plotAx((df[df.CHAMP == c]['PCT_H'],df[df.CHAMP == c]['PCT_F'],df3.cv_score), ax)
    ax.set_title(c)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-070b1c29e04a> in <module>()
#      18 for c, ax in zip(champs, axis):
#      19     df3 = df2[df2.champ == c]
# ---> 20     plotAx((df[df.CHAMP == c]['PCT_H'],df[df.CHAMP == c]['PCT_F'],df3.cv_score), ax)
#      21     ax.set_title(c)
#      22 plt.show()
#
# /home/igormago/anaconda3/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'cv_score'

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

df =  pd.read_csv("../data/matches-tables.csv") 
df = df[df.championship_id < 90]
champs_cv = []

features = list(df.columns)
features.remove('match_id')
features.remove('column_result')
features.remove('match_date')
features.remove('goals_home')
features.remove('goals_away')

target = 'column_result'

X = df[features]
y = df[target]

X_new = SelectKBest(chi2, k=2).fit_transform(X, y)

# %%
from sklearn import datasets
from sklearn import metrics
from sklearn.ensemble import ExtraTreesClassifier
# load the iris datasets
df = pd.read_csv("../data/matches-tables.csv") 
df = df[(df.championship_id <= 90)]
df = df[df.odd_home.notnull()]
df = df[df.odd_draw.notnull()]
df = df[df.odd_away.notnull()]

features = list(df.columns)
features.remove('match_id')
features.remove('column_result')
features.remove('match_date')
features.remove('goals_home')
features.remove('goals_away')

target = 'column_result'

X = df[features]
y = df[target]

from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
# create the RFE model and select 3 attributes
rfe = RFE(model, 15)
rfe = rfe.fit(X, y)
# summarize the selection of the attributes
print(rfe.support_)
print(rfe.ranking_)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import cross_validation

mt =  pd.read_csv("../data/matches-tables.csv") 
champs_cv = []

for i in range(90,91):
    df = mt[mt.championship_id == i]
    df = df[df.odd_home.notnull()]
    df = df[df.odd_draw.notnull()]
    df = df[df.odd_away.notnull()]

mt =  pd.read_csv("../data/matches-tables.csv") 
champs_cv = []

for i in range(90,91):
    df = mt[mt.championship_id == i]
    df = df[df.odd_home.notnull()]
    df = df[df.odd_draw.notnull()]
    df = df[df.odd_away.notnull()]

    features = ['odd_home','odd_draw','odd_away','h_matches_played',
                'h_loses','h_matches_played_home','h_winners_home',
                'h_draws_home','h_loses_home','h_goals_against_home','h_loses_away','a_winners','a_goals_for',
                 'a_winners_home']
    
    target = 'column_result'

    X = df[features]
    y = df[target]
    
    clf = RandomForestClassifier(n_estimators=1000)
    clf.fit(X, y)
    scores = cross_validation.cross_val_score(clf, X, y, cv=10)
    champs_cv.append(scores.mean())
    print("%0.2f" % (scores.mean()))
    

    
print(champs_cv)

    features = ['odd_home','odd_draw','odd_away','h_matches_played',
                'h_loses','h_matches_played_home','h_winners_home',
                'h_draws_home','h_loses_home','h_goals_against_home','h_loses_away','a_winners','a_goals_for',
                 'a_winners_home']
    
    target = 'column_result'

    X = df[features]
    y = df[target]
    
    clf = RandomForestClassifier(n_estimators=1000)
    clf.fit(X, y)
    scores = cross_validation.cross_val_score(clf, X, y, cv=10)
    champs_cv.append(scores.mean())
    print("%0.2f" % (scores.mean()))
    

    
print(champs_cv)
# Out:
#   File "<ipython-input-11-ab87eb439f1e>", line 42
#     features = ['odd_home','odd_draw','odd_away','h_matches_played',
#     ^
# IndentationError: unexpected indent

# %%
x = [0.48868342026236766, 0.48278161620266885, 0.48154308154308156, 0.48981684113263058, 0.4774066576698156, 
     0.43005554426607057, 0.4389521100047416, 0.49032547585179176, 0.4839568515884306, 0.45279392174129018, 
     0.44761712840660206, 0.43161778319673055, 0.56097281492018325, 0.51209498972656864, 0.57609846688794053, 
     0.52419575445891231, 0.48376068376068371, 0.52306719675140734, 0.5361085145295672, 0.497380275011854,
     0.4609372530425162, 0.54880670143828048, 0.54787385129490396, 0.53108029081713293, 0.42487141276614959, 
     0.51135823793718527, 0.47866287339971547, 0.54463286594865545, 0.48143274853801171, 0.42710149420675736, 
     0.48844351870667663, 0.46046535257061577, 0.51755966492808603, 0.52426110320847163, 0.44189766689766685, 
     0.47799510036352144, 0.5647378147378147, 0.50014800514800517, 0.42378028404344192, 0.48624263361105469, 
     0.42757027704396122, 0.39935897435897438, 0.4215979137031769, 0.4821303258145363, 0.39211590132642765, 
     0.41607227528280166, 0.43846858136331823, 0.45803242513768827, 0.50604788999525829, 0.41762040235724446, 
     0.44702261772339635, 0.46425287356321843, 0.49353355580274388, 0.44310344827586212, 0.44618067694263469,
     0.45224455744477998, 0.46835505058530646, 0.52474972191323688, 0.47529185867895551, 0.46446421950315164, 
     0.49912714097496708, 0.44973649538866922, 0.54301712779973654, 0.48952898550724644, 0.43858695652173907, 
     0.5521480331262939, 0.54666666666666663, 0.47807971014492756, 0.50387931034482758, 0.53024392181789293, 
     0.54688013136288993, 0.47424837120610197, 0.48943243815880078, 0.5679638752052546, 0.49143492769744163, 
     0.56684119921606024, 0.49183537263626248, 0.45794957360029664, 0.48261772339636633, 0.51896922506488696]

z = [0.42990753911806545, 0.47499096841202099, 0.49394779394779392, 0.44598454730033676, 0.46225091488249381, 
     0.4518638939691571, 0.43675912754860124, 0.4905549910813069, 0.50879518616360708, 0.43612296507033343,
    0.44823522770891194, 0.44188985978459672, 0.52057057057057066, 0.52349849849849839, 0.55723486644539277, 
     0.51592594618910403, 0.52179487179487172, 0.49018400992085204, 0.51222312538102011, 0.52462462462462456,
    0.4797139244507666, 0.53558558558558556, 0.48570175438596486, 0.54707455575876629, 0.41127458285353019, 
     0.47405089299826136, 0.48370080606922727, 0.54427363453679245, 0.49743559348822519, 0.41145852330062854, 
     0.48602102102102107, 0.50968502336923383, 0.49073810652758026, 0.50548443180022118, 0.48704666204666208, 
     0.45825825825825817, 0.56217371217371215, 0.48144674749937905, 0.42527986633249792, 0.49121339384497287, 
     0.43101221522274152, 0.38607068607068606, 0.4185277382645804, 0.48445697577276531, 0.4052060157323315, 
     0.45108988687936058, 0.44356510645984332, 0.4407058880743091, 0.50882995777732609, 0.40851452956716122,
     0.45381164256581386, 0.46457614942528735, 0.4561698183166481, 0.46756465517241386, 0.40630462418560309, 
     0.43830446527888134, 0.47558980878224483, 0.50527252502780873, 0.46156682027649776, 0.48113088616981836, 
     0.44560276679841893, 0.45923913043478259, 0.49477931488801052, 0.46436627140974968, 0.47223084886128364, 
     0.50758987389422183, 0.53231818181818169, 0.46576086956521739, 0.52479143492769753, 0.50374622596535834,
     0.53962233169129725, 0.49701281847555495, 0.49357116372689236, 0.57486042692939254, 0.48350150961385674, 
     0.54305630594840826, 0.49904629482493779, 0.43860215053763441, 0.48217278457545421, 0.51908416759362253]

# %%
df =  pd.read_csv("../data/resumeMatchesByYear_avg.csv") 

championships = ['Brazil - Série A','Spain - La Liga 1',
          'Germany - Bundesliga','Italy - Serie A', 'England - Premier League',
          'France - Ligue 1', 'Portugal - Primeira Liga', 'Netherlands - Eredivise']

list_champs_cv = []

for c in champs:
    for i in range(1,11):
        list_champs_cv.append(c)
    

df2 = pd.DataFrame()
df2['champ'] = list_champs_cv
df2['cv_score'] = x
df2['cv_score_fs'] = z

fig, ((ax1,ax2),(ax3,ax4),(ax5,ax6),(ax7,ax8)) = plt.subplots(4,2)
fig.set_figwidth(16)
fig.set_figheight(10)
fig.tight_layout()

yticks= np.arange(0.30,0.69,0.05)
xticks = ('Home','Favorite','Random Forest','RF - Feature Selection')

def plotAx(df, ax):
    ax.boxplot(df, showmeans=True)
    ax.set_ylabel("Prob. Winner")
    ax.set_yticks(yticks)
    ax.set_xticklabels(xticks)

axis = [ax1,ax2,ax3,ax4,ax5,ax6,ax7,ax8]
for c, ax in zip(champs, axis):
    df3 = df2[df2.champ == c]
    plotAx((df[df.CHAMP == c]['PCT_H'],df[df.CHAMP == c]['PCT_F'],df3.cv_score, df3.cv_score_fs), ax)
    ax.set_title(c)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-79dd1371c397> in <module>()
#      14 df2 = pd.DataFrame()
#      15 df2['champ'] = list_champs_cv
# ---> 16 df2['cv_score'] = x
#      17 df2['cv_score_fs'] = z
#      18
#
# NameError: name 'x' is not defined

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import cross_validation

df =  pd.read_csv("../data/matches-tables.csv") 
df = df[(df.championship_id < 11) | ((df.championship_id > 21) & (df.championship_id < 91))]
champs_cv = []

res1 = df[(df.odd_home <= df.odd_draw) & (df.odd_home <= df.odd_away)]
res2 = df[(df.odd_draw <= df.odd_home) & (df.odd_draw <= df.odd_away)]
res3 = df[(df.odd_away < df.odd_home) & (df.odd_away < df.odd_draw)]

res4 = res1[res1.column_result == 'H']
res5 = res2[res2.column_result == 'D']
res6 = res3[res3.column_result == 'A']
    
print(len(res1), len(res4), len(res1) - len(res4), len(res4)/len(res1))
print(len(res2), len(res5), len(res2) - len(res5), len(res5)/len(res2))
print(len(res3), len(res6), len(res3) - len(res6), len(res6)/len(res3))
# Out:
# 19819 10802 9017 0.5450325445279782
# 52 25 27 0.4807692307692308
# 6611 3260 3351 0.49311753138708214

# %%
df = pd.read_csv("../data/matches-tables.csv") 
#df = df[(df.championship_id < 2)]

df = df[(df.championship_id < 11) | ((df.championship_id > 21) & (df.championship_id < 91))]
df = df[df.odd_home.notnull()]
df = df[df.odd_draw.notnull()]
df = df[df.odd_away.notnull()]

features = list(df.columns)
features.remove('match_id')
features.remove('column_result')
features.remove('match_date')
features.remove('goals_home')
features.remove('goals_away')

target = 'column_result'

clf = RandomForestClassifier(n_estimators=1000)
# scores = cross_validation.cross_val_score(clf, X, y, cv=10)
# print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))

X = df[features]
y = df[target]
clf.fit(X, y)
predicted = cross_validation.cross_val_predict(clf, X,
                                               y, cv=10)


cor=0
h = d = a = hc = he = dc = de = ac = ae = 0
for i,z in zip(y,predicted):
   
    if (i == 'H'):
        h = h + 1
        if (z == 'H'):
            hc = hc + 1
        else:
            he = he + 1
    elif (i == 'D'):
        d = d + 1
        if (z == 'D'):
            dc = dc + 1
        else:
            de = de + 1
    else:
        a = a + 1
        if (z == 'A'):
            ac = ac + 1
        else:
            ae = ae + 1

print(h, hc, he, hc/h, he/h)
print(d, dc, de, dc/d, de/d)
print(a, ac, ae, ac/a, ae/a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-25ae3856a936> in <module>()
#      23 X = df[features]
#      24 y = df[target]
# ---> 25 clf.fit(X, y)
#      26 predicted = cross_validation.cross_val_predict(clf, X,
#      27                                                y, cv=10)
#
# /home/igormago/anaconda3/lib/python3.5/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     210         """
#     211         # Validate or convert input data
# --> 212         X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     213         if issparse(X):
#     214             # Pre-sort indices to avoid that each individual tree of the
#
# ...
